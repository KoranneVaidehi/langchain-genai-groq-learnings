# %% [markdown]
# ### Structed output

# %% [markdown]
# ### Pydantic

# %%
import os

from langchain_groq import ChatGroq
model = ChatGroq(model="llama-3.1-8b-instant")

# %%
model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001C9E142D160>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001C9E142DE80>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from pydantic import BaseModel , Field

class Movie(BaseModel):
    title:str=Field(description="the title of the movie"),
    year:int=Field(description="The year the movie was released"),
    director:str=Field(description="The director of the movie"),
    rating:float=Field(description="The movie rating out of 10")

# %%
model_with_structure=model.with_structured_output(Movie)
model_with_structure
# Out:
# c:\Users\vaidehi koranne\OneDrive\Desktop\LangchainProject\.venv\Lib\site-packages\pydantic\json_schema.py:2448: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='the title of the movie'),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)
# c:\Users\vaidehi koranne\OneDrive\Desktop\LangchainProject\.venv\Lib\site-packages\pydantic\json_schema.py:2448: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='The year the movie was released'),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)
# c:\Users\vaidehi koranne\OneDrive\Desktop\LangchainProject\.venv\Lib\site-packages\pydantic\json_schema.py:2448: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='The director of the movie'),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)
# RunnableBinding(bound=ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001C9E142D160>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001C9E142DE80>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'Movie', 'description': '', 'parameters': {'properties': {'title': {'type': 'string'}, 'year': {'type': 'integer'}, 'director': {'type': 'string'}, 'rating': {'description': 'The movie rating out of 10', 'type': 'number'}}, 'required': ['rating'], 'type': 'object'}}}], 'ls_structured_output_format': {'kwargs': {'method': 'function_calling'}, 'schema': {'type': 'function', 'function': {'name': 'Movie', 'description': '', 'parameters': {'properties': {'title': {'type': 'string'}, 'year': {'type': 'integer'}, 'director': {'type': 'string'}, 'rating': {'description': 'The movie rating out of 10', 'type': 'number'}}, 'required': ['rating'], 'type': 'object'}}}}, 'tool_choice': {'type': 'function', 'function': {'name': 'Movie'}}}, config={}, config_factories=[])
# | PydanticToolsParser(first_tool_only=True, tools=[<class '__main__.Movie'>])

# %%
model.invoke("Provide the details about the movie Inception")
# Out:
# AIMessage(content='**Inception** is a 2010 science fiction action film written and directed by Christopher Nolan. The film is a mind-bending, visually stunning, and thought-provoking exploration of the concept of shared dreaming and the blurring of reality.\n\n**Plot:**\n\nThe movie follows Cobb (Leonardo DiCaprio), a skilled thief who specializes in entering people\'s dreams and stealing their secrets. Cobb is hired by a wealthy businessman named Saito (Ken Watanabe) to perform a task known as "inception" – planting an idea in someone\'s mind instead of stealing one. Saito wants Cobb to convince Robert Fischer (Cillian Murphy), the son of a dying business magnate, to dissolve his father\'s company.\n\nCobb assembles a team of experts to help him with the task: Arthur (Joseph Gordon-Levitt), a point man; Ariadne (Ellen Page), an architect; Eames (Tom Hardy), a forger; and Saito, who joins the team as a passenger. The team must navigate the complexities of shared dreaming, where the subconscious can create multiple levels of reality, and the dreamer can lose track of what\'s real and what\'s a dream.\n\n**Themes:**\n\n* **Reality and Perception:** The movie explores the idea that reality is subjective and can be manipulated. Cobb\'s journey raises questions about the nature of reality and whether it\'s possible to distinguish between what\'s real and what\'s a dream.\n* **Guilt and Redemption:** Cobb\'s backstory reveals a tragic event that has left him with a deep sense of guilt and responsibility. The movie follows his journey towards redemption and forgiveness.\n* **Memory and Identity:** The film delves into the concept of memory and how it shapes our identities. Cobb\'s memories of his wife, Mal (Marion Cotillard), are a central theme, and the movie raises questions about the nature of memory and its relationship to reality.\n\n**Visuals and Style:**\n\n* **Intricate Action Sequences:** The movie features some of the most complex and visually stunning action sequences in cinema history, including a hotel corridor fight and a zero-gravity hotel lobby chase.\n* **Non-Linear Storytelling:** The film\'s narrative is presented in a non-linear fashion, with multiple timelines and levels of reality.\n* **Dream Logic:** The movie\'s use of dream logic creates a sense of disorientation and confusion, mirroring Cobb\'s experience as he navigates the dream world.\n\n**Cast:**\n\n* **Leonardo DiCaprio** as Cobb\n* **Joseph Gordon-Levitt** as Arthur\n* **Ellen Page** as Ariadne\n* **Tom Hardy** as Eames\n* **Ken Watanabe** as Saito\n* **Marion Cotillard** as Mal\n* **Cillian Murphy** as Robert Fischer\n\n**Awards and Reception:**\n\n* **Academy Awards:** The movie was nominated for eight Academy Awards, including Best Picture, Best Director, and Best Cinematography.\n* **Critical Reception:** Inception received widespread critical acclaim, with many praising its originality, visuals, and performances.\n* **Box Office:** The movie was a commercial success, grossing over $825 million worldwide.\n\n**Impact and Legacy:**\n\n* **Influence on Popular Culture:** Inception has had a significant influence on popular culture, with its concepts and visuals inspiring countless fan art, cosplay, and fan fiction.\n* **Cinematic Legacy:** The movie has been named one of the greatest films of all time by various publications and critics, including Empire, Rolling Stone, and The Guardian.\n* **Christopher Nolan\'s Career:** Inception marked a new level of success for Christopher Nolan, cementing his reputation as one of the most innovative and respected directors in the industry.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 775, 'prompt_tokens': 43, 'total_tokens': 818, 'completion_time': 1.043428178, 'completion_tokens_details': None, 'prompt_time': 0.002100841, 'prompt_tokens_details': None, 'queue_time': 0.045323064, 'total_time': 1.045529019}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4 ...

# %%
model_with_structure.invoke("Provide the details about the movie Inception")
# Out:
# Movie(title='Inception', year=2010, director='Christopher Nolan', rating=8.8)
